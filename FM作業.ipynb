# %%
import pandas as pd
import statsmodels.api as sm
import statistics

# 从 CSV 文件中读取数据
data = pd.read_csv('fama_french_data.csv')

# 获取表头名称清单
header_list = data.columns.tolist()

# 第一阶段回归
# 提取第一阶段自变量
X_first_stage = data[['Mkt-RF']]  # 自变量：Mkt-RF

betas = []
ri_rfs = []
resid_var = []

for col in header_list[4:]:
    
    # 因变量：Agric
    y_first_stage = data[col]
    # 添加截距项
    X_first_stage = sm.add_constant(X_first_stage)

    # 创建并拟合第一阶段线性回归模型
    model_first_stage = sm.OLS(y_first_stage, X_first_stage).fit()
    
    print(model_first_stage.summary())
    # 获取均方回归（MSR）
    print('Mean Square Regression:', model_first_stage.mse_model, '\n')
    # 获取均方误差（MSE）
    print('Mean Square Error:',model_first_stage.mse_resid, '\n')

    # 获取第一阶段回归的残差
    betas.append( model_first_stage.params[1])
    ri_rfs.append(statistics.mean(y_first_stage))
    resid_var.append(statistics.variance(model_first_stage.resid))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Agric   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     39.65
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           4.39e-08
# Time:                        17:29:39   Log-Likelihood:                -184.28
# No. Observations:                  60   AIC:                             372.6
# Df Residuals:                      58   BIC:                             376.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0299      0.737     -0.041      0.968      -1.505       1.445
# Mkt-RF         1.2010      0.191      6.297      0.000       0.819       1.583
# ==============================================================================
# Omnibus:                        4.756   Durbin-Watson:                   2.481
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                5.950
# Skew:                          -0.076   Prob(JB):                       0.0510
# Kurtosis:                       4.535   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1117.548586464341
#
# Mean Square Error: 28.183657101189524
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Food    R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     39.03
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           5.31e-08
# Time:                        17:29:39   Log-Likelihood:                -136.18
# No. Observations:                  60   AIC:                             276.4
# Df Residuals:                      58   BIC:                             280.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6834      0.330      2.068      0.043       0.022       1.345
# Mkt-RF         0.5345      0.086      6.248      0.000       0.363       0.706
# ==============================================================================
# Omnibus:                        3.338   Durbin-Watson:                   2.331
# Prob(Omnibus):                  0.188   Jarque-Bera (JB):                1.758
# Skew:                           0.069   Prob(JB):                        0.415
# Kurtosis:                       2.173   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 221.3293951584053
#
# Mean Square Error: 5.670418934050482
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Soda    R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     13.55
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           0.000511
# Time:                        17:29:39   Log-Likelihood:                -159.00
# No. Observations:                  60   AIC:                             322.0
# Df Residuals:                      58   BIC:                             326.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6762      0.483      1.399      0.167      -0.292       1.644
# Mkt-RF         0.4607      0.125      3.681      0.001       0.210       0.711
# ==============================================================================
# Omnibus:                        4.287   Durbin-Watson:                   2.295
# Prob(Omnibus):                  0.117   Jarque-Bera (JB):                4.176
# Skew:                          -0.633   Prob(JB):                        0.124
# Kurtosis:                       2.738   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 164.44513018406838
#
# Mean Square Error: 12.135619910619512
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Beer    R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     21.86
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.80e-05
# Time:                        17:29:39   Log-Likelihood:                -138.53
# No. Observations:                  60   AIC:                             281.1
# Df Residuals:                      58   BIC:                             285.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8883      0.344      2.585      0.012       0.200       1.576
# Mkt-RF         0.4160      0.089      4.675      0.000       0.238       0.594
# ==============================================================================
# Omnibus:                        1.655   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.437   Jarque-Bera (JB):                1.497
# Skew:                          -0.258   Prob(JB):                        0.473
# Kurtosis:                       2.423   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 134.05242028528875
#
# Mean Square Error: 6.13246686289732
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Smoke   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     24.89
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           5.85e-06
# Time:                        17:29:39   Log-Likelihood:                -166.07
# No. Observations:                  60   AIC:                             336.1
# Df Residuals:                      58   BIC:                             340.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7772      0.544      1.429      0.158      -0.312       1.866
# Mkt-RF         0.7024      0.141      4.989      0.000       0.421       0.984
# ==============================================================================
# Omnibus:                        3.122   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.210   Jarque-Bera (JB):                2.717
# Skew:                          -0.421   Prob(JB):                        0.257
# Kurtosis:                       2.384   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 382.20624777051717
#
# Mean Square Error: 15.358021561427869
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Toys    R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     56.25
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           4.24e-10
# Time:                        17:29:39   Log-Likelihood:                -162.87
# No. Observations:                  60   AIC:                             329.7
# Df Residuals:                      58   BIC:                             333.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0434      0.516     -0.084      0.933      -1.076       0.989
# Mkt-RF         1.0011      0.133      7.500      0.000       0.734       1.268
# ==============================================================================
# Omnibus:                        0.105   Durbin-Watson:                   2.491
# Prob(Omnibus):                  0.949   Jarque-Bera (JB):                0.042
# Skew:                           0.054   Prob(JB):                        0.979
# Kurtosis:                       2.929   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 776.4268274535709
#
# Mean Square Error: 13.804251566892452
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Fun     R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     62.41
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           9.02e-11
# Time:                        17:29:39   Log-Likelihood:                -178.16
# No. Observations:                  60   AIC:                             360.3
# Df Residuals:                      58   BIC:                             364.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0050      0.665     -0.008      0.994      -1.337       1.327
# Mkt-RF         1.3606      0.172      7.900      0.000       1.016       1.705
# ==============================================================================
# Omnibus:                        2.030   Durbin-Watson:                   1.740
# Prob(Omnibus):                  0.362   Jarque-Bera (JB):                1.406
# Skew:                          -0.362   Prob(JB):                        0.495
# Kurtosis:                       3.198   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1434.2563600003573
#
# Mean Square Error: 22.982826091947864
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Books   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.665
# Method:                 Least Squares   F-statistic:                     118.1
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.30e-15
# Time:                        17:29:39   Log-Likelihood:                -149.45
# No. Observations:                  60   AIC:                             302.9
# Df Residuals:                      58   BIC:                             307.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.412      0.009      0.993      -0.821       0.829
# Mkt-RF         1.1597      0.107     10.867      0.000       0.946       1.373
# ==============================================================================
# Omnibus:                        3.419   Durbin-Watson:                   2.240
# Prob(Omnibus):                  0.181   Jarque-Bera (JB):                2.532
# Skew:                          -0.464   Prob(JB):                        0.282
# Kurtosis:                       3.390   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1042.048936702748
#
# Mean Square Error: 8.824574079837676
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Hshld   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.500
# Method:                 Least Squares   F-statistic:                     59.91
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.67e-10
# Time:                        17:29:39   Log-Likelihood:                -133.41
# No. Observations:                  60   AIC:                             270.8
# Df Residuals:                      58   BIC:                             275.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1228      0.316      0.389      0.699      -0.509       0.755
# Mkt-RF         0.6324      0.082      7.740      0.000       0.469       0.796
# ==============================================================================
# Omnibus:                        2.765   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.251   Jarque-Bera (JB):                1.594
# Skew:                           0.073   Prob(JB):                        0.451
# Kurtosis:                       2.215   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 309.82378796769933
#
# Mean Square Error: 5.171463741936218
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Clths   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     44.36
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.09e-08
# Time:                        17:29:39   Log-Likelihood:                -169.00
# No. Observations:                  60   AIC:                             342.0
# Df Residuals:                      58   BIC:                             346.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5338      0.571      0.935      0.354      -0.609       1.677
# Mkt-RF         0.9847      0.148      6.660      0.000       0.689       1.281
# ==============================================================================
# Omnibus:                        7.860   Durbin-Watson:                   2.426
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                9.527
# Skew:                          -0.487   Prob(JB):                      0.00853
# Kurtosis:                       4.692   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 751.161753920444
#
# Mean Square Error: 16.932652518613033
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Hlth    R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     56.78
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           3.69e-10
# Time:                        17:29:39   Log-Likelihood:                -163.98
# No. Observations:                  60   AIC:                             332.0
# Df Residuals:                      58   BIC:                             336.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3436      0.525      0.654      0.516      -0.708       1.395
# Mkt-RF         1.0247      0.136      7.535      0.000       0.753       1.297
# ==============================================================================
# Omnibus:                        6.750   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                8.967
# Skew:                          -0.330   Prob(JB):                       0.0113
# Kurtosis:                       4.775   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 813.512753308491
#
# Mean Square Error: 14.327027241807624
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  MedEq   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     104.8
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.30e-14
# Time:                        17:29:39   Log-Likelihood:                -141.18
# No. Observations:                  60   AIC:                             286.4
# Df Residuals:                      58   BIC:                             290.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0849      0.359      0.236      0.814      -0.634       0.804
# Mkt-RF         0.9518      0.093     10.235      0.000       0.766       1.138
# ==============================================================================
# Omnibus:                        2.266   Durbin-Watson:                   2.153
# Prob(Omnibus):                  0.322   Jarque-Bera (JB):                1.625
# Skew:                           0.050   Prob(JB):                        0.444
# Kurtosis:                       3.800   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 701.8143184014001
#
# Mean Square Error: 6.699737355148274
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Drugs   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     54.19
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           7.25e-10
# Time:                        17:29:39   Log-Likelihood:                -134.82
# No. Observations:                  60   AIC:                             273.6
# Df Residuals:                      58   BIC:                             277.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0990      0.323      3.402      0.001       0.452       1.746
# Mkt-RF         0.6156      0.084      7.361      0.000       0.448       0.783
# ==============================================================================
# Omnibus:                        1.201   Durbin-Watson:                   2.222
# Prob(Omnibus):                  0.549   Jarque-Bera (JB):                1.147
# Skew:                          -0.195   Prob(JB):                        0.564
# Kurtosis:                       2.446   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 293.645769560857
#
# Mean Square Error: 5.419265352399018
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Chems   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     238.7
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           3.20e-22
# Time:                        17:29:39   Log-Likelihood:                -135.88
# No. Observations:                  60   AIC:                             275.8
# Df Residuals:                      58   BIC:                             280.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1927      0.329     -0.586      0.560      -0.851       0.466
# Mkt-RF         1.3154      0.085     15.451      0.000       1.145       1.486
# ==============================================================================
# Omnibus:                        1.806   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.405   Jarque-Bera (JB):                1.044
# Skew:                           0.210   Prob(JB):                        0.593
# Kurtosis:                       3.491   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1340.5157451784644
#
# Mean Square Error: 5.615406548647172
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rubbr   R-squared:                       0.714
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     144.9
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           2.08e-17
# Time:                        17:29:39   Log-Likelihood:                -141.20
# No. Observations:                  60   AIC:                             286.4
# Df Residuals:                      58   BIC:                             290.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2723      0.359      0.758      0.452      -0.447       0.992
# Mkt-RF         1.1196      0.093     12.037      0.000       0.933       1.306
# ==============================================================================
# Omnibus:                        0.350   Durbin-Watson:                   2.165
# Prob(Omnibus):                  0.839   Jarque-Bera (JB):                0.376
# Skew:                          -0.171   Prob(JB):                        0.829
# Kurtosis:                       2.817   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 971.2331449394393
#
# Mean Square Error: 6.703183707940699
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Txtls   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     110.3
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           4.86e-15
# Time:                        17:29:39   Log-Likelihood:                -155.50
# No. Observations:                  60   AIC:                             315.0
# Df Residuals:                      58   BIC:                             319.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8507      0.456      1.865      0.067      -0.062       1.764
# Mkt-RF         1.2400      0.118     10.504      0.000       1.004       1.476
# ==============================================================================
# Omnibus:                        1.641   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.440   Jarque-Bera (JB):                1.479
# Skew:                          -0.253   Prob(JB):                        0.477
# Kurtosis:                       2.420   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1191.273765585981
#
# Mean Square Error: 10.79689611058654
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  BldMt   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     214.1
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           3.99e-21
# Time:                        17:29:39   Log-Likelihood:                -145.70
# No. Observations:                  60   AIC:                             295.4
# Df Residuals:                      58   BIC:                             299.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4024      0.387     -1.039      0.303      -1.178       0.373
# Mkt-RF         1.4670      0.100     14.632      0.000       1.266       1.668
# ==============================================================================
# Omnibus:                        2.794   Durbin-Watson:                   2.315
# Prob(Omnibus):                  0.247   Jarque-Bera (JB):                2.329
# Skew:                           0.482   Prob(JB):                        0.312
# Kurtosis:                       3.024   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1667.3736510853296
#
# Mean Square Error: 7.787706331862141
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Cnstr   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     162.2
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.90e-18
# Time:                        17:29:39   Log-Likelihood:                -156.36
# No. Observations:                  60   AIC:                             316.7
# Df Residuals:                      58   BIC:                             320.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8296      0.463     -1.793      0.078      -1.756       0.096
# Mkt-RF         1.5253      0.120     12.736      0.000       1.286       1.765
# ==============================================================================
# Omnibus:                        2.789   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.248   Jarque-Bera (JB):                1.615
# Skew:                          -0.086   Prob(JB):                        0.446
# Kurtosis:                       2.215   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1802.3795495103755
#
# Mean Square Error: 11.111516359016505
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Steel   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     179.7
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           2.04e-19
# Time:                        17:29:39   Log-Likelihood:                -157.25
# No. Observations:                  60   AIC:                             318.5
# Df Residuals:                      58   BIC:                             322.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.8458      0.470     -3.931      0.000      -2.786      -0.906
# Mkt-RF         1.6297      0.122     13.407      0.000       1.386       1.873
# ==============================================================================
# Omnibus:                        0.580   Durbin-Watson:                   1.808
# Prob(Omnibus):                  0.748   Jarque-Bera (JB):                0.672
# Skew:                           0.012   Prob(JB):                        0.715
# Kurtosis:                       2.482   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 2057.6801777659493
#
# Mean Square Error: 11.447708975299724
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  FabPr   R-squared:                       0.524
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                     63.79
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           6.45e-11
# Time:                        17:29:39   Log-Likelihood:                -186.39
# No. Observations:                  60   AIC:                             376.8
# Df Residuals:                      58   BIC:                             381.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0640      0.763     -1.394      0.169      -2.592       0.464
# Mkt-RF         1.5777      0.198      7.987      0.000       1.182       1.973
# ==============================================================================
# Omnibus:                        0.413   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.813   Jarque-Bera (JB):                0.572
# Skew:                          -0.072   Prob(JB):                        0.751
# Kurtosis:                       2.544   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1928.492011910519
#
# Mean Square Error: 30.232577352117485
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Mach    R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     220.7
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.99e-21
# Time:                        17:29:39   Log-Likelihood:                -149.49
# No. Observations:                  60   AIC:                             303.0
# Df Residuals:                      58   BIC:                             307.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8514      0.413     -2.064      0.044      -1.677      -0.026
# Mkt-RF         1.5866      0.107     14.856      0.000       1.373       1.800
# ==============================================================================
# Omnibus:                        0.383   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.826   Jarque-Bera (JB):                0.547
# Skew:                           0.055   Prob(JB):                        0.761
# Kurtosis:                       2.545   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1950.1958871282507
#
# Mean Square Error: 8.836823210432453
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ElcEq   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     176.5
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           3.05e-19
# Time:                        17:29:39   Log-Likelihood:                -145.66
# No. Observations:                  60   AIC:                             295.3
# Df Residuals:                      58   BIC:                             299.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6504      0.387     -1.680      0.098      -1.425       0.124
# Mkt-RF         1.3311      0.100     13.285      0.000       1.131       1.532
# ==============================================================================
# Omnibus:                        0.202   Durbin-Watson:                   2.372
# Prob(Omnibus):                  0.904   Jarque-Bera (JB):                0.019
# Skew:                          -0.043   Prob(JB):                        0.990
# Kurtosis:                       3.017   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1372.8078626097667
#
# Mean Square Error: 7.778592340061494
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Autos   R-squared:                       0.695
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     131.9
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.44e-16
# Time:                        17:29:39   Log-Likelihood:                -165.94
# No. Observations:                  60   AIC:                             335.9
# Df Residuals:                      58   BIC:                             340.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7344      0.543     -1.353      0.181      -1.821       0.352
# Mkt-RF         1.6134      0.141     11.483      0.000       1.332       1.895
# ==============================================================================
# Omnibus:                        0.458   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.795   Jarque-Bera (JB):                0.074
# Skew:                          -0.016   Prob(JB):                        0.964
# Kurtosis:                       3.169   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 2016.6642125464227
#
# Mean Square Error: 15.294340013567423
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Aero    R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     156.7
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           3.97e-18
# Time:                        17:29:39   Log-Likelihood:                -132.35
# No. Observations:                  60   AIC:                             268.7
# Df Residuals:                      58   BIC:                             272.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1295      0.310      0.418      0.678      -0.491       0.750
# Mkt-RF         1.0049      0.080     12.519      0.000       0.844       1.166
# ==============================================================================
# Omnibus:                        0.723   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.697   Jarque-Bera (JB):                0.800
# Skew:                          -0.125   Prob(JB):                        0.670
# Kurtosis:                       2.493   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 782.3697688913342
#
# Mean Square Error: 4.991881312218374
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Ships   R-squared:                       0.658
# Model:                            OLS   Adj. R-squared:                  0.652
# Method:                 Least Squares   F-statistic:                     111.4
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           4.06e-15
# Time:                        17:29:39   Log-Likelihood:                -178.05
# No. Observations:                  60   AIC:                             360.1
# Df Residuals:                      58   BIC:                             364.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1456      0.664      0.219      0.827      -1.184       1.475
# Mkt-RF         1.8141      0.172     10.553      0.000       1.470       2.158
# ==============================================================================
# Omnibus:                        8.783   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):               10.942
# Skew:                           0.546   Prob(JB):                      0.00421
# Kurtosis:                       4.785   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ...
# Omnibus:                        1.912   Durbin-Watson:                   1.450
# Prob(Omnibus):                  0.384   Jarque-Bera (JB):                1.664
# Skew:                          -0.275   Prob(JB):                        0.435
# Kurtosis:                       2.398   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 746.556883144819
#
# Mean Square Error: 6.076692675664042
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Whlsl   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     358.0
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.72e-26
# Time:                        17:29:39   Log-Likelihood:                -106.74
# No. Observations:                  60   AIC:                             217.5
# Df Residuals:                      58   BIC:                             221.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0937      0.202      0.463      0.645      -0.311       0.499
# Mkt-RF         0.9911      0.052     18.921      0.000       0.886       1.096
# ==============================================================================
# Omnibus:                        2.086   Durbin-Watson:                   1.769
# Prob(Omnibus):                  0.352   Jarque-Bera (JB):                1.345
# Skew:                          -0.146   Prob(JB):                        0.511
# Kurtosis:                       3.673   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 761.0652008200955
#
# Mean Square Error: 2.1257734054006554
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rtail   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     116.8
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.62e-15
# Time:                        17:29:39   Log-Likelihood:                -129.42
# No. Observations:                  60   AIC:                             262.8
# Df Residuals:                      58   BIC:                             267.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5277      0.295      1.787      0.079      -0.063       1.119
# Mkt-RF         0.8261      0.076     10.807      0.000       0.673       0.979
# ==============================================================================
# Omnibus:                        3.101   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.212   Jarque-Bera (JB):                2.483
# Skew:                           0.211   Prob(JB):                        0.289
# Kurtosis:                       3.903   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 528.657115894189
#
# Mean Square Error: 4.5264142087208805
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Meals   R-squared:                       0.541
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     68.44
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           2.14e-11
# Time:                        17:29:39   Log-Likelihood:                -131.35
# No. Observations:                  60   AIC:                             266.7
# Df Residuals:                      58   BIC:                             270.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7021      0.305      2.302      0.025       0.092       1.313
# Mkt-RF         0.6531      0.079      8.273      0.000       0.495       0.811
# ==============================================================================
# Omnibus:                        5.127   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                4.479
# Skew:                          -0.663   Prob(JB):                        0.107
# Kurtosis:                       3.185   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 330.4189750334591
#
# Mean Square Error: 4.828150401721971
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Banks   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     193.0
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           4.21e-20
# Time:                        17:29:39   Log-Likelihood:                -138.27
# No. Observations:                  60   AIC:                             280.5
# Df Residuals:                      58   BIC:                             284.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3852      0.342     -1.126      0.265      -1.070       0.300
# Mkt-RF         1.2306      0.089     13.891      0.000       1.053       1.408
# ==============================================================================
# Omnibus:                        0.168   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.919   Jarque-Bera (JB):                0.319
# Skew:                           0.106   Prob(JB):                        0.853
# Kurtosis:                       2.713   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1173.3385709627341
#
# Mean Square Error: 6.08080909259654
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Insur   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     269.8
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.75e-23
# Time:                        17:29:39   Log-Likelihood:                -120.22
# No. Observations:                  60   AIC:                             244.4
# Df Residuals:                      58   BIC:                             248.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1270      0.253      0.501      0.618      -0.380       0.634
# Mkt-RF         1.0771      0.066     16.427      0.000       0.946       1.208
# ==============================================================================
# Omnibus:                        1.572   Durbin-Watson:                   2.384
# Prob(Omnibus):                  0.456   Jarque-Bera (JB):                1.109
# Skew:                           0.330   Prob(JB):                        0.574
# Kurtosis:                       3.093   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 898.8437578948832
#
# Mean Square Error: 3.3309744041112124
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RlEst   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     224.9
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.28e-21
# Time:                        17:29:39   Log-Likelihood:                -142.29
# No. Observations:                  60   AIC:                             288.6
# Df Residuals:                      58   BIC:                             292.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5079      0.366     -1.388      0.170      -1.240       0.225
# Mkt-RF         1.4207      0.095     14.997      0.000       1.231       1.610
# ==============================================================================
# Omnibus:                        0.385   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.825   Jarque-Bera (JB):                0.307
# Skew:                          -0.168   Prob(JB):                        0.858
# Kurtosis:                       2.903   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1563.807328329941
#
# Mean Square Error: 6.953089741437806
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Fin     R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           1.68e-24
# Time:                        17:29:39   Log-Likelihood:                -136.15
# No. Observations:                  60   AIC:                             276.3
# Df Residuals:                      58   BIC:                             280.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6650      0.330     -2.013      0.049      -1.326      -0.004
# Mkt-RF         1.4746      0.086     17.244      0.000       1.303       1.646
# ==============================================================================
# Omnibus:                        2.901   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.235   Jarque-Bera (JB):                2.486
# Skew:                           0.499   Prob(JB):                        0.289
# Kurtosis:                       2.983   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 1684.7364343081358
#
# Mean Square Error: 5.665700098135592
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Other   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.684
# Method:                 Least Squares   F-statistic:                     128.7
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           2.36e-16
# Time:                        17:29:39   Log-Likelihood:                -137.21
# No. Observations:                  60   AIC:                             278.4
# Df Residuals:                      58   BIC:                             282.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0044      0.336     -0.013      0.990      -0.677       0.669
# Mkt-RF         0.9873      0.087     11.344      0.000       0.813       1.162
# ==============================================================================
# Omnibus:                        4.813   Durbin-Watson:                   1.740
# Prob(Omnibus):                  0.090   Jarque-Bera (JB):                4.624
# Skew:                           0.676   Prob(JB):                       0.0990
# Kurtosis:                       2.851   Cond. No.                         4.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean Square Regression: 755.229321955507
#
# Mean Square Error: 5.86905433410045

# %%
# 被解釋變數
y_second_stage = ri_rfs

# 解釋變數
X_second_stage = pd.DataFrame.from_dict({'beta': betas, 'resid': resid_var})

# 添加截距项
X_second_stage = sm.add_constant(X_second_stage)

# 创建并拟合第二阶段线性回归模型
model_second_stage = sm.OLS(y_second_stage, X_second_stage).fit()
print(model_second_stage.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.566
# Model:                            OLS   Adj. R-squared:                  0.547
# Method:                 Least Squares   F-statistic:                     29.39
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           6.83e-09
# Time:                        16:09:56   Log-Likelihood:                -32.449
# No. Observations:                  48   AIC:                             70.90
# Df Residuals:                      45   BIC:                             76.51
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8519      0.205      9.053      0.000       1.440       2.264
# beta          -0.0414      0.172     -0.240      0.811      -0.388       0.306
# resid         -0.0312      0.004     -7.554      0.000      -0.040      -0.023
# ==============================================================================
# Omnibus:                       12.240   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.373
# Skew:                           0.815   Prob(JB):                     0.000278
# Kurtosis:                       5.351   Cond. No.                         80.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# According to our first time-series regression result, we can see that almost each estimated beta coefficient statistically different from zero, except for Gold industry, which has p-value of 0.689. In terms of alpha, there are some industries like Fin, Meals, PerSv, Coal, Mines, Guns, Mach, Steel, Drugs, Beer, Food having alpha statistically different from 0, which means these industries could have other factors infecting their returns.

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# 从 CSV 文件中读取时间序列数据
data = pd.read_csv('fama_french_data.csv')

# 获取表头名称清单
header_list = data.columns.tolist()

for col in header_list:
    # 提取时间序列数据列（假设列名为 'Column_name'）
    time_series = data[col]

    # 执行 ADF 检验
    result = adfuller(time_series)

    # 打印 ADF 检验结果
    print(col)
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('Critical Values:', result[4])
# Out:
# Date
# ADF Statistic: 0.0052447960215658085
# p-value: 0.9589636837611726
# Critical Values: {'1%': -3.5745892596209488, '5%': -2.9239543084490744, '10%': -2.6000391840277777}
# Mkt-RF
# ADF Statistic: -9.524950944377833
# p-value: 2.9951113094297337e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# SMB
# ADF Statistic: -9.43071752469358
# p-value: 5.199095858768456e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# HML
# ADF Statistic: -6.1340812488949785
# p-value: 8.267483067767465e-08
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Agric
# ADF Statistic: -4.9672836764221975
# p-value: 2.5751072712580397e-05
# Critical Values: {'1%': -3.552928203580539, '5%': -2.9147306250000002, '10%': -2.595137155612245}
# Food
# ADF Statistic: -9.651293575453984
# p-value: 1.432425313792439e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Soda
# ADF Statistic: -9.136244435509436
# p-value: 2.9304655189497316e-15
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Beer
# ADF Statistic: -8.8329434689613
# p-value: 1.7497960608372167e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Smoke
# ADF Statistic: -6.297398080799166
# p-value: 3.4786974968381565e-08
# Critical Values: {'1%': -3.548493559596539, '5%': -2.912836594776334, '10%': -2.594129155766944}
# Toys
# ADF Statistic: -8.875347109950022
# p-value: 1.362731228941755e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Fun
# ADF Statistic: -7.597872373921532
# p-value: 2.433088942824348e-11
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Books
# ADF Statistic: -10.657300334494167
# p-value: 4.499889873832462e-19
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Hshld
# ADF Statistic: -8.389398478870621
# p-value: 2.3892837822925444e-13
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Clths
# ADF Statistic: -6.57237503041688
# p-value: 7.877381352918647e-09
# Critical Values: {'1%': -3.548493559596539, '5%': -2.912836594776334, '10%': -2.594129155766944}
# Hlth
# ADF Statistic: -7.755379311377525
# p-value: 9.769379559349071e-12
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# MedEq
# ADF Statistic: -9.488050285219623
# p-value: 3.716621756775421e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Drugs
# ADF Statistic: -5.73072463430902
# p-value: 6.609912980320586e-07
# Critical Values: {'1%': -3.5552728880540942, '5%': -2.9157312396694217, '10%': -2.5956695041322315}
# Chems
# ADF Statistic: -9.63324292090925
# p-value: 1.5914008212935286e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Rubbr
# ADF Statistic: -4.1201909415829725
# p-value: 0.0008967151337240588
# Critical Values: {'1%': -3.5552728880540942, '5%': -2.9157312396694217, '10%': -2.5956695041322315}
# Txtls
# ADF Statistic: -8.568301687160107
# p-value: 8.329803482004303e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# BldMt
# ADF Statistic: -9.47095564253513
# p-value: 4.1076844166124995e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Cnstr
# ADF Statistic: -8.911684754358845
# p-value: 1.0999630669895578e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Steel
# ADF Statistic: -8.13699453947373
# p-value: 1.0526906304519232e-12
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# FabPr
# ADF Statistic: -8.182025330966225
# p-value: 8.083242348385803e-13
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Mach
# ADF Statistic: -9.318131187515021
# p-value: 1.0061378321118812e-15
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# ElcEq
# ADF Statistic: -8.796691100876552
# p-value: 2.1668187488237994e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Autos
# ADF Statistic: -8.670046564151198
# p-value: 4.572399056607515e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Aero
# ADF Statistic: -8.704452209829595
# p-value: 3.732836270504088e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Ships
# ADF Statistic: -8.229933034916627
# p-value: 6.10160306987751e-13
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Guns
# ADF Statistic: -6.951533697463027
# p-value: 9.664600825194928e-10
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Gold
# ADF Statistic: -8.18623992511975
# p-value: 7.885773988518254e-13
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Mines
# ADF Statistic: -9.811476011339224
# p-value: 5.641913960054071e-17
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Coal
# ADF Statistic: -9.150196737320366
# p-value: 2.6995033626112688e-15
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Oil
# ADF Statistic: -7.525241207718788
# p-value: 3.6996312636995503e-11
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Util
# ADF Statistic: -10.059965712081219
# p-value: 1.3416142206164479e-17
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Telcm
# ADF Statistic: -9.158361787560322
# p-value: 2.5728951643500253e-15
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# PerSv
# ADF Statistic: -10.936719207761094
# p-value: 9.518919254911561e-20
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# BusSv
# ADF Statistic: -9.533217301547372
# p-value: 2.853809404891934e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Comps
# ADF Statistic: -9.198571125874176
# p-value: 2.0310308573040742e-15
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Chips
# ADF Statistic: -8.277520502212008
# p-value: 4.613467820205195e-13
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# LabEq
# ADF Statistic: -7.580839339969145
# p-value: 2.684626809008918e-11
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Paper
# ADF Statistic: -8.72458830487014
# p-value: 3.314917065224829e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Boxes
# ADF Statistic: -8.760157556614082
# p-value: 2.6877077101087572e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Trans
# ADF Statistic: -7.9404592367611
# p-value: 3.3246736996382906e-12
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Whlsl
# ADF Statistic: -9.037363325796688
# p-value: 5.245128483629395e-15
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Rtail
# ADF Statistic: -9.660961608377738
# p-value: 1.353939785875827e-16
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Meals
# ADF Statistic: -8.16695858998787
# p-value: 8.83035432265062e-13
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Banks
# ADF Statistic: -8.778276530801527
# p-value: 2.415352388380988e-14
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Insur
# ADF Statistic: -9.2357064010851
# p-value: 1.6327124764276026e-15
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# RlEst
# ADF Statistic: -4.373388368368139
# p-value: 0.00033073027104385836
# Critical Values: {'1%': -3.560242358792829, '5%': -2.9178502070837, '10%': -2.5967964150943397}
# Fin
# ADF Statistic: -8.43066784894349
# p-value: 1.8739746809045141e-13
# Critical Values: {'1%': -3.5463945337644063, '5%': -2.911939409384601, '10%': -2.5936515282964665}
# Other
# ADF Statistic: -4.335717237295275
# p-value: 0.000385030045072822
# Critical Values: {'1%': -3.560242358792829, '5%': -2.9178502070837, '10%': -2.5967964150943397}
