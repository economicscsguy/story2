# %%
import pandas as pd
import statsmodels.api as sm
import statistics

# 从 CSV 文件中读取数据
data = pd.read_csv('fama_french_data.csv')

# 获取表头名称清单
header_list = data.columns.tolist()

# 第一阶段回归
# 提取第一阶段自变量
X_first_stage = data[['Mkt-RF','SMB','HML']]  # 自变量：Mkt-RF、SMB、HML

betas1 = []
betas2 = []
betas3 = []
ri_rfs = []
resid_var = []

for col in header_list[4:]:
    
    # 因变量：Agric
    y_first_stage = data[col]
    # 添加截距项
    X_first_stage = sm.add_constant(X_first_stage)

    # 创建并拟合第一阶段线性回归模型
    model_first_stage = sm.OLS(y_first_stage, X_first_stage).fit()
    
    print(model_first_stage.summary())
    
    # 获取 SSTO（总平方和）
    SSTO = model_first_stage.centered_tss

    # 获取 SSR（回归平方和）
    SSR = model_first_stage.ess

    # 获取 SSE（残差平方和）
    SSE = model_first_stage.ssr + model_first_stage.centered_tss

    # 获取 MSR（均方回归）
    MSR = model_first_stage.mse_model

    # 获取 MSE（均方误差）
    MSE = model_first_stage.mse_resid

    print("SSTO:", SSTO)
    print("SSR:", SSR)
    print("SSE:", SSE)
    print("MSR:", MSR)
    print("MSE:", MSE)

    # 获取第一阶段回归的残差
    betas1.append( model_first_stage.params[1])
    betas2.append( model_first_stage.params[2])
    betas3.append( model_first_stage.params[3])
    ri_rfs.append(statistics.mean(y_first_stage))
    resid_var.append(statistics.variance(model_first_stage.resid))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Agric   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.374
# Method:                 Least Squares   F-statistic:                     12.77
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.81e-06
# Time:                        22:24:39   Log-Likelihood:                -184.27
# No. Observations:                  60   AIC:                             376.5
# Df Residuals:                      56   BIC:                             384.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0101      0.771     -0.013      0.990      -1.555       1.535
# Mkt-RF         1.1923      0.223      5.347      0.000       0.746       1.639
# SMB            0.0155      0.378      0.041      0.967      -0.741       0.772
# HML            0.0498      0.410      0.122      0.904      -0.771       0.871
# ==============================================================================
# Omnibus:                        4.625   Durbin-Watson:                   2.488
# Prob(Omnibus):                  0.099   Jarque-Bera (JB):                5.709
# Skew:                          -0.050   Prob(JB):                       0.0576
# Kurtosis:                       4.508   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 2752.2006983333335
# SSR: 1117.9896484488513
# SSE: 4386.411748217815
# MSR: 372.6632161496171
# MSE: 29.18234017650861
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Food    R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.380
# Method:                 Least Squares   F-statistic:                     13.06
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.42e-06
# Time:                        22:24:39   Log-Likelihood:                -135.71
# No. Observations:                  60   AIC:                             279.4
# Df Residuals:                      56   BIC:                             287.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6184      0.343      1.801      0.077      -0.069       1.306
# Mkt-RF         0.5800      0.099      5.844      0.000       0.381       0.779
# SMB           -0.1540      0.168     -0.916      0.364      -0.491       0.183
# HML           -0.0698      0.182     -0.383      0.703      -0.435       0.296
# ==============================================================================
# Omnibus:                        1.963   Durbin-Watson:                   2.324
# Prob(Omnibus):                  0.375   Jarque-Bera (JB):                1.301
# Skew:                           0.030   Prob(JB):                        0.522
# Kurtosis:                       2.281   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 550.2136933333333
# SSR: 226.44151262645767
# SSE: 873.9858740402088
# MSR: 75.48050420881923
# MSE: 5.78164608405135
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Soda    R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     11.50
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           5.61e-06
# Time:                        22:24:39   Log-Likelihood:                -150.91
# No. Observations:                  60   AIC:                             309.8
# Df Residuals:                      56   BIC:                             318.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2455      0.442      0.555      0.581      -0.640       1.131
# Mkt-RF         0.7074      0.128      5.533      0.000       0.451       0.964
# SMB           -0.6864      0.217     -3.169      0.002      -1.120      -0.252
# HML           -0.7655      0.235     -3.258      0.002      -1.236      -0.295
# ==============================================================================
# Omnibus:                        7.613   Durbin-Watson:                   2.279
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):                6.898
# Skew:                          -0.793   Prob(JB):                       0.0318
# Kurtosis:                       3.492   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 868.311085
# SSR: 330.941614507909
# SSE: 1405.6805554920911
# MSR: 110.31387150263633
# MSE: 9.595883401644484
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Beer    R-squared:                       0.327
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     9.050
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           5.58e-05
# Time:                        22:24:39   Log-Likelihood:                -136.26
# No. Observations:                  60   AIC:                             280.5
# Df Residuals:                      56   BIC:                             288.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7210      0.346      2.081      0.042       0.027       1.415
# Mkt-RF         0.5167      0.100      5.158      0.000       0.316       0.717
# SMB           -0.2962      0.170     -1.746      0.086      -0.636       0.044
# HML           -0.2706      0.184     -1.470      0.147      -0.639       0.098
# ==============================================================================
# Omnibus:                        0.812   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.666   Jarque-Bera (JB):                0.881
# Skew:                          -0.253   Prob(JB):                        0.644
# Kurtosis:                       2.691   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 489.7354983333333
# SSR: 159.9069844802877
# SSE: 819.5640121863789
# MSR: 53.3023281600959
# MSE: 5.889794890232957
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Smoke   R-squared:                       0.459
# Model:                            OLS   Adj. R-squared:                  0.430
# Method:                 Least Squares   F-statistic:                     15.85
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.41e-07
# Time:                        22:24:39   Log-Likelihood:                -158.34
# No. Observations:                  60   AIC:                             324.7
# Df Residuals:                      56   BIC:                             333.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3392      0.501      0.678      0.501      -0.664       1.342
# Mkt-RF         0.9914      0.145      6.850      0.000       0.701       1.281
# SMB           -0.9300      0.245     -3.793      0.000      -1.421      -0.439
# HML           -0.5674      0.266     -2.133      0.037      -1.100      -0.035
# ==============================================================================
# Omnibus:                        0.739   Durbin-Watson:                   2.234
# Prob(Omnibus):                  0.691   Jarque-Bera (JB):                0.548
# Skew:                          -0.233   Prob(JB):                        0.760
# Kurtosis:                       2.954   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1272.9714983333336
# SSR: 584.4700757629912
# SSE: 1961.472920903676
# MSR: 194.82335858766373
# MSE: 12.294668260184684
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Toys    R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     18.49
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.84e-08
# Time:                        22:24:39   Log-Likelihood:                -162.55
# No. Observations:                  60   AIC:                             333.1
# Df Residuals:                      56   BIC:                             341.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0712      0.537     -0.133      0.895      -1.147       1.004
# Mkt-RF         0.9945      0.155      6.406      0.000       0.684       1.306
# SMB            0.0923      0.263      0.351      0.727      -0.435       0.619
# HML           -0.1739      0.285     -0.609      0.545      -0.745       0.398
# ==============================================================================
# Omnibus:                        0.411   Durbin-Watson:                   2.491
# Prob(Omnibus):                  0.814   Jarque-Bera (JB):                0.242
# Skew:                           0.155   Prob(JB):                        0.886
# Kurtosis:                       2.976   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1577.0734183333332
# SSR: 784.8819219044185
# SSE: 2369.264914762248
# MSR: 261.62730730147285
# MSE: 14.146276721944904
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Fun     R-squared:                       0.566
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     24.34
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.26e-10
# Time:                        22:24:39   Log-Likelihood:                -175.03
# No. Observations:                  60   AIC:                             358.1
# Df Residuals:                      56   BIC:                             366.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1209      0.661     -0.183      0.856      -1.445       1.204
# Mkt-RF         1.3385      0.191      7.002      0.000       0.956       1.721
# SMB            0.3534      0.324      1.091      0.280      -0.295       1.002
# HML           -0.6954      0.351     -1.979      0.053      -1.399       0.008
# ==============================================================================
# Omnibus:                        1.121   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.571   Jarque-Bera (JB):                0.802
# Skew:                          -0.283   Prob(JB):                        0.670
# Kurtosis:                       3.017   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 2767.2602733333333
# SSR: 1566.2485138584561
# SSE: 3968.2720328082105
# MSR: 522.0828379528187
# MSE: 21.44663856205138
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Books   R-squared:                       0.706
# Model:                            OLS   Adj. R-squared:                  0.690
# Method:                 Least Squares   F-statistic:                     44.82
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           6.67e-15
# Time:                        22:24:39   Log-Likelihood:                -146.04
# No. Observations:                  60   AIC:                             300.1
# Df Residuals:                      56   BIC:                             308.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2245      0.408      0.551      0.584      -0.592       1.041
# Mkt-RF         1.0095      0.118      8.562      0.000       0.773       1.246
# SMB            0.4966      0.200      2.487      0.016       0.097       0.897
# HML            0.2604      0.217      1.202      0.235      -0.174       0.694
# ==============================================================================
# Omnibus:                        4.431   Durbin-Watson:                   2.253
# Prob(Omnibus):                  0.109   Jarque-Bera (JB):                3.440
# Skew:                          -0.502   Prob(JB):                        0.179
# Kurtosis:                       3.608   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1553.8742333333332
# SSR: 1096.9825144688057
# SSE: 2010.7659521978608
# MSR: 365.66083815626854
# MSE: 8.158780694009419
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Hshld   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     24.06
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.93e-10
# Time:                        22:24:39   Log-Likelihood:                -129.86
# No. Observations:                  60   AIC:                             267.7
# Df Residuals:                      56   BIC:                             276.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0211      0.311      0.068      0.946      -0.603       0.645
# Mkt-RF         0.7284      0.090      8.090      0.000       0.548       0.909
# SMB           -0.3917      0.153     -2.568      0.013      -0.697      -0.086
# HML            0.0283      0.165      0.171      0.865      -0.303       0.360
# ==============================================================================
# Omnibus:                        1.379   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.502   Jarque-Bera (JB):                1.092
# Skew:                          -0.070   Prob(JB):                        0.579
# Kurtosis:                       2.354   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 609.768685
# SSR: 343.3523721809811
# SSE: 876.1849978190189
# MSR: 114.4507907269937
# MSE: 4.75743415748248
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Clths   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.456
# Method:                 Least Squares   F-statistic:                     17.52
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.83e-08
# Time:                        22:24:39   Log-Likelihood:                -166.18
# No. Observations:                  60   AIC:                             340.4
# Df Residuals:                      56   BIC:                             348.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3581      0.570      0.628      0.533      -0.785       1.501
# Mkt-RF         1.0213      0.165      6.192      0.000       0.691       1.352
# SMB            0.1092      0.279      0.391      0.697      -0.451       0.669
# HML           -0.6661      0.303     -2.198      0.032      -1.273      -0.059
# ==============================================================================
# Omnibus:                       10.541   Durbin-Watson:                   2.523
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               13.867
# Skew:                          -0.645   Prob(JB):                     0.000975
# Kurtosis:                       4.970   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1733.2556
# SSR: 839.1211999576258
# SSE: 2627.390000042374
# MSR: 279.7070666525419
# MSE: 15.966685715042397
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Hlth    R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                     25.20
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.89e-10
# Time:                        22:24:39   Log-Likelihood:                -158.83
# No. Observations:                  60   AIC:                             325.7
# Df Residuals:                      56   BIC:                             334.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6892      0.505      1.366      0.177      -0.322       1.700
# Mkt-RF         0.7921      0.146      5.429      0.000       0.500       1.084
# SMB            0.7611      0.247      3.079      0.003       0.266       1.256
# HML            0.4227      0.268      1.576      0.121      -0.114       0.960
# ==============================================================================
# Omnibus:                        8.361   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):               18.069
# Skew:                           0.006   Prob(JB):                     0.000119
# Kurtosis:                       5.688   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1644.4803333333332
# SSR: 944.6972904335603
# SSE: 2344.263376233106
# MSR: 314.8990968111868
# MSE: 12.496125766067374
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  MedEq   R-squared:                       0.697
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     42.95
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.53e-14
# Time:                        22:24:39   Log-Likelihood:                -136.31
# No. Observations:                  60   AIC:                             280.6
# Df Residuals:                      56   BIC:                             289.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2329      0.347      0.672      0.505      -0.462       0.927
# Mkt-RF         0.8196      0.100      8.175      0.000       0.619       1.020
# SMB            0.5240      0.170      3.085      0.003       0.184       0.864
# HML            0.0009      0.184      0.005      0.996      -0.368       0.370
# ==============================================================================
# Omnibus:                        0.229   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.892   Jarque-Bera (JB):                0.139
# Skew:                           0.113   Prob(JB):                        0.933
# Kurtosis:                       2.934   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1090.399085
# SSR: 760.0382537792705
# SSE: 1420.7599162207296
# MSR: 253.34608459309015
# MSE: 5.899300557513028
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Drugs   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.524
# Method:                 Least Squares   F-statistic:                     22.67
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           9.77e-10
# Time:                        22:24:39   Log-Likelihood:                -130.76
# No. Observations:                  60   AIC:                             269.5
# Df Residuals:                      56   BIC:                             277.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9302      0.316      2.943      0.005       0.297       1.563
# Mkt-RF         0.6801      0.091      7.441      0.000       0.497       0.863
# SMB           -0.0730      0.155     -0.472      0.639      -0.383       0.237
# HML           -0.4782      0.168     -2.847      0.006      -0.815      -0.142
# ==============================================================================
# Omnibus:                        0.599   Durbin-Watson:                   2.257
# Prob(Omnibus):                  0.741   Jarque-Bera (JB):                0.694
# Skew:                          -0.216   Prob(JB):                        0.707
# Kurtosis:                       2.697   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 607.96316
# SSR: 333.415823003354
# SSE: 882.510496996646
# MSR: 111.13860766778465
# MSE: 4.90263101779725
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Chems   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     77.92
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           5.62e-20
# Time:                        22:24:39   Log-Likelihood:                -135.55
# No. Observations:                  60   AIC:                             279.1
# Df Residuals:                      56   BIC:                             287.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2536      0.342     -0.741      0.462      -0.939       0.432
# Mkt-RF         1.3448      0.099     13.586      0.000       1.147       1.543
# SMB           -0.0638      0.168     -0.380      0.705      -0.400       0.272
# HML           -0.1385      0.182     -0.761      0.450      -0.503       0.226
# ==============================================================================
# Omnibus:                        1.369   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.504   Jarque-Bera (JB):                0.676
# Skew:                           0.113   Prob(JB):                        0.713
# Kurtosis:                       3.468   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1666.2093250000005
# SSR: 1344.1802268100873
# SSE: 1988.2384231899136
# MSR: 448.06007560336246
# MSE: 5.750519610534162
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rubbr   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     58.97
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           2.47e-17
# Time:                        22:24:39   Log-Likelihood:                -136.00
# No. Observations:                  60   AIC:                             280.0
# Df Residuals:                      56   BIC:                             288.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3965      0.345      1.150      0.255      -0.294       1.088
# Mkt-RF         0.9951      0.100      9.977      0.000       0.795       1.195
# SMB            0.5224      0.169      3.091      0.003       0.184       0.861
# HML           -0.0745      0.183     -0.406      0.686      -0.442       0.293
# ==============================================================================
# Omnibus:                        1.351   Durbin-Watson:                   2.107
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                1.167
# Skew:                           0.155   Prob(JB):                        0.558
# Kurtosis:                       2.391   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1360.0177999999999
# SSR: 1033.0341948530256
# SSE: 1687.001405146974
# MSR: 344.3447316176752
# MSE: 5.838992949053112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Txtls   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     45.18
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           5.70e-15
# Time:                        22:24:39   Log-Likelihood:                -150.57
# No. Observations:                  60   AIC:                             309.1
# Df Residuals:                      56   BIC:                             317.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9419      0.440      2.142      0.037       0.061       1.823
# Mkt-RF         1.1147      0.127      8.767      0.000       0.860       1.369
# SMB            0.5893      0.215      2.736      0.008       0.158       1.021
# HML           -0.2417      0.234     -1.034      0.306      -0.710       0.226
# ==============================================================================
# Omnibus:                        0.918   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.632   Jarque-Bera (JB):                0.947
# Skew:                          -0.161   Prob(JB):                        0.623
# Kurtosis:                       2.476   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1817.4937400000001
# SSR: 1286.1078873430763
# SSE: 2348.8795926569237
# MSR: 428.7026291143588
# MSE: 9.489033083159354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  BldMt   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     93.73
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           8.18e-22
# Time:                        22:24:39   Log-Likelihood:                -138.21
# No. Observations:                  60   AIC:                             284.4
# Df Residuals:                      56   BIC:                             292.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1126      0.358     -0.315      0.754      -0.829       0.604
# Mkt-RF         1.2654      0.103     12.229      0.000       1.058       1.473
# SMB            0.6781      0.175      3.868      0.000       0.327       1.029
# HML            0.3183      0.190      1.674      0.100      -0.063       0.699
# ==============================================================================
# Omnibus:                        4.062   Durbin-Watson:                   2.369
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                3.096
# Skew:                           0.496   Prob(JB):                        0.213
# Kurtosis:                       3.504   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 2119.060618333334
# SSR: 1767.1302888876464
# SSE: 2470.9909477790216
# MSR: 589.0434296292154
# MSE: 6.284470168672991
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Cnstr   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     66.71
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.75e-18
# Time:                        22:24:39   Log-Likelihood:                -150.77
# No. Observations:                  60   AIC:                             309.5
# Df Residuals:                      56   BIC:                             317.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5028      0.441     -1.139      0.259      -1.387       0.381
# Mkt-RF         1.3127      0.128     10.289      0.000       1.057       1.568
# SMB            0.6746      0.216      3.121      0.003       0.242       1.108
# HML            0.4412      0.234      1.881      0.065      -0.029       0.911
# ==============================================================================
# Omnibus:                        2.530   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.282   Jarque-Bera (JB):                1.993
# Skew:                          -0.295   Prob(JB):                        0.369
# Kurtosis:                       2.330   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 2446.8474983333326
# SSR: 1911.8623099852143
# SSE: 2981.832686681451
# MSR: 637.2874366617381
# MSE: 9.553306934787827
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Steel   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     66.56
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.84e-18
# Time:                        22:24:39   Log-Likelihood:                -154.02
# No. Observations:                  60   AIC:                             316.0
# Df Residuals:                      56   BIC:                             324.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5867      0.466     -3.407      0.001      -2.520      -0.654
# Mkt-RF         1.5069      0.135     11.189      0.000       1.237       1.777
# SMB            0.2574      0.228      1.128      0.264      -0.200       0.714
# HML            0.6019      0.248      2.432      0.018       0.106       1.098
# ==============================================================================
# Omnibus:                        0.146   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.930   Jarque-Bera (JB):                0.127
# Skew:                          -0.097   Prob(JB):                        0.939
# Kurtosis:                       2.885   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 2721.6472983333333
# SSR: 2125.5172892662913
# SSE: 3317.7773074003753
# MSR: 708.5057630887637
# MSE: 10.645178733340035
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  FabPr   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                     28.37
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           2.74e-11
# Time:                        22:24:39   Log-Likelihood:                -180.92
# No. Observations:                  60   AIC:                             369.8
# Df Residuals:                      56   BIC:                             378.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5782      0.729     -0.793      0.431      -2.039       0.883
# Mkt-RF         1.2343      0.211      5.854      0.000       0.812       1.657
# SMB            1.1700      0.357      3.276      0.002       0.455       1.886
# HML            0.5033      0.387      1.299      0.199      -0.273       1.280
# ==============================================================================
# Omnibus:                        1.294   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.524   Jarque-Bera (JB):                1.074
# Skew:                          -0.095   Prob(JB):                        0.584
# Kurtosis:                       2.373   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 3681.981498333333
# SSR: 2220.8071642197765
# SSE: 5143.15583244689
# MSR: 740.2690547399255
# MSE: 26.092398823456364
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Mach    R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     80.36
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           2.80e-20
# Time:                        22:24:39   Log-Likelihood:                -146.52
# No. Observations:                  60   AIC:                             301.0
# Df Residuals:                      56   BIC:                             309.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6653      0.411     -1.619      0.111      -1.489       0.158
# Mkt-RF         1.4494      0.119     12.195      0.000       1.211       1.687
# SMB            0.4826      0.201      2.397      0.020       0.079       0.886
# HML            0.1615      0.218      0.740      0.463      -0.276       0.599
# ==============================================================================
# Omnibus:                        0.805   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.669   Jarque-Bera (JB):                0.813
# Skew:                           0.065   Prob(JB):                        0.666
# Kurtosis:                       2.445   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 2462.731633333333
# SSR: 1998.5178678299344
# SSE: 2926.9453988367313
# MSR: 666.1726226099781
# MSE: 8.289531526846403
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ElcEq   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     65.28
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           2.80e-18
# Time:                        22:24:39   Log-Likelihood:                -142.46
# No. Observations:                  60   AIC:                             292.9
# Df Residuals:                      56   BIC:                             301.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4907      0.384     -1.277      0.207      -1.260       0.279
# Mkt-RF         1.2039      0.111     10.838      0.000       0.981       1.426
# SMB            0.4720      0.188      2.508      0.015       0.095       0.849
# HML            0.0859      0.204      0.421      0.676      -0.323       0.495
# ==============================================================================
# Omnibus:                        0.972   Durbin-Watson:                   2.378
# Prob(Omnibus):                  0.615   Jarque-Bera (JB):                0.366
# Skew:                           0.049   Prob(JB):                        0.833
# Kurtosis:                       3.370   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1823.9662183333335
# SSR: 1418.3962080444298
# SSE: 2229.536228622237
# MSR: 472.79873601480995
# MSE: 7.242321612301849
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Autos   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     50.01
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           7.49e-16
# Time:                        22:24:39   Log-Likelihood:                -162.44
# No. Observations:                  60   AIC:                             332.9
# Df Residuals:                      56   BIC:                             341.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4649      0.536     -0.867      0.389      -1.538       0.609
# Mkt-RF         1.4170      0.155      9.144      0.000       1.107       1.727
# SMB            0.6845      0.263      2.608      0.012       0.159       1.210
# HML            0.2471      0.285      0.868      0.389      -0.323       0.818
# ==============================================================================
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1603      0.205      0.781      0.438      -0.251       0.572
# Mkt-RF         0.9392      0.059     15.816      0.000       0.820       1.058
# SMB            0.1903      0.101      1.891      0.064      -0.011       0.392
# HML            0.0417      0.109      0.382      0.704      -0.177       0.260
# ==============================================================================
# Omnibus:                        1.745   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.418   Jarque-Bera (JB):                1.039
# Skew:                          -0.029   Prob(JB):                        0.595
# Kurtosis:                       3.642   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 884.3600583333334
# SSR: 768.4691849622648
# SSE: 1000.2509317044021
# MSR: 256.1563949874216
# MSE: 2.069479881626227
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rtail   R-squared:                       0.713
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     46.35
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.44e-15
# Time:                        22:24:40   Log-Likelihood:                -125.08
# No. Observations:                  60   AIC:                             258.2
# Df Residuals:                      56   BIC:                             266.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4080      0.288      1.419      0.161      -0.168       0.984
# Mkt-RF         0.8553      0.083     10.289      0.000       0.689       1.022
# SMB            0.0481      0.141      0.341      0.734      -0.234       0.330
# HML           -0.4300      0.153     -2.815      0.007      -0.736      -0.124
# ==============================================================================
# Omnibus:                        3.451   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.178   Jarque-Bera (JB):                2.729
# Skew:                          -0.292   Prob(JB):                        0.256
# Kurtosis:                       3.867   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 791.1891400000001
# SSR: 564.0313230083589
# SSE: 1018.3469569916413
# MSR: 188.01044100278628
# MSE: 4.056389589136449
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Meals   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     28.44
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           2.63e-11
# Time:                        22:24:40   Log-Likelihood:                -126.96
# No. Observations:                  60   AIC:                             261.9
# Df Residuals:                      56   BIC:                             270.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5926      0.297      1.997      0.051      -0.002       1.187
# Mkt-RF         0.6728      0.086      7.843      0.000       0.501       0.845
# SMB            0.0870      0.145      0.599      0.552      -0.204       0.378
# HML           -0.4326      0.158     -2.744      0.008      -0.748      -0.117
# ==============================================================================
# Omnibus:                        2.893   Durbin-Watson:                   1.757
# Prob(Omnibus):                  0.235   Jarque-Bera (JB):                2.743
# Skew:                          -0.510   Prob(JB):                        0.254
# Kurtosis:                       2.762   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 610.4516983333334
# SSR: 368.5761922433399
# SSE: 852.327204423327
# MSR: 122.85873074777997
# MSE: 4.3192054658927415
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Banks   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     120.0
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           2.34e-24
# Time:                        22:24:40   Log-Likelihood:                -122.07
# No. Observations:                  60   AIC:                             252.1
# Df Residuals:                      56   BIC:                             260.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0298      0.273     -0.109      0.913      -0.578       0.518
# Mkt-RF         1.0782      0.079     13.636      0.000       0.920       1.237
# SMB            0.2555      0.134      1.908      0.062      -0.013       0.524
# HML            0.9144      0.145      6.292      0.000       0.623       1.205
# ==============================================================================
# Omnibus:                        1.508   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.470   Jarque-Bera (JB):                0.890
# Skew:                           0.270   Prob(JB):                        0.641
# Kurtosis:                       3.255   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1526.0254983333334
# SSR: 1320.5350087325207
# SSE: 1731.515987934146
# MSR: 440.1783362441736
# MSE: 3.669473028585942
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Insur   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     116.7
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           4.54e-24
# Time:                        22:24:40   Log-Likelihood:                -112.74
# No. Observations:                  60   AIC:                             233.5
# Df Residuals:                      56   BIC:                             241.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3444      0.234      1.471      0.147      -0.125       0.813
# Mkt-RF         0.9507      0.068     14.047      0.000       0.815       1.086
# SMB            0.3577      0.115      3.119      0.003       0.128       0.587
# HML            0.3760      0.124      3.023      0.004       0.127       0.625
# ==============================================================================
# Omnibus:                        0.717   Durbin-Watson:                   2.242
# Prob(Omnibus):                  0.699   Jarque-Bera (JB):                0.762
# Skew:                           0.061   Prob(JB):                        0.683
# Kurtosis:                       2.462   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1092.0402733333335
# SSR: 941.4689181267397
# SSE: 1242.6116285399273
# MSR: 313.82297270891326
# MSE: 2.688774200117746
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RlEst   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     78.82
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           4.33e-20
# Time:                        22:24:40   Log-Likelihood:                -140.25
# No. Observations:                  60   AIC:                             288.5
# Df Residuals:                      56   BIC:                             296.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4074      0.370     -1.100      0.276      -1.149       0.334
# Mkt-RF         1.3312      0.107     12.435      0.000       1.117       1.546
# SMB            0.3545      0.181      1.955      0.056      -0.009       0.718
# HML            0.0019      0.197      0.010      0.992      -0.392       0.396
# ==============================================================================
# Omnibus:                        0.732   Durbin-Watson:                   1.486
# Prob(Omnibus):                  0.694   Jarque-Bera (JB):                0.340
# Skew:                          -0.173   Prob(JB):                        0.843
# Kurtosis:                       3.130   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1967.0865333333336
# SSR: 1590.4296120379056
# SSE: 2343.7434546287614
# MSR: 530.1432040126352
# MSE: 6.726016451704071
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Fin     R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     135.5
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           1.22e-25
# Time:                        22:24:40   Log-Likelihood:                -127.20
# No. Observations:                  60   AIC:                             262.4
# Df Residuals:                      56   BIC:                             270.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3865      0.298     -1.297      0.200      -0.983       0.210
# Mkt-RF         1.3498      0.086     15.671      0.000       1.177       1.522
# SMB            0.2326      0.146      1.594      0.117      -0.060       0.525
# HML            0.6874      0.158      4.342      0.000       0.370       1.004
# ==============================================================================
# Omnibus:                        2.932   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.231   Jarque-Bera (JB):                2.844
# Skew:                           0.490   Prob(JB):                        0.241
# Kurtosis:                       2.580   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 2013.34704
# SSR: 1769.4950704950656
# SSE: 2257.1990095049346
# MSR: 589.8316901650219
# MSE: 4.35449945544526
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Other   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     56.70
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           5.64e-17
# Time:                        22:24:40   Log-Likelihood:                -130.41
# No. Observations:                  60   AIC:                             268.8
# Df Residuals:                      56   BIC:                             277.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0442      0.314      0.141      0.889      -0.585       0.674
# Mkt-RF         1.0251      0.091     11.281      0.000       0.843       1.207
# SMB           -0.3213      0.154     -2.087      0.041      -0.630      -0.013
# HML            0.4492      0.167      2.690      0.009       0.115       0.784
# ==============================================================================
# Omnibus:                        1.905   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.386   Jarque-Bera (JB):                1.807
# Skew:                           0.336   Prob(JB):                        0.405
# Kurtosis:                       2.479   Cond. No.                         4.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# SSTO: 1095.634473333333
# SSR: 824.2729029344719
# SSE: 1366.9960437321943
# MSR: 274.7576343114906
# MSE: 4.845742328551092

# %%
# 被解釋變數
y_second_stage = ri_rfs

# 解釋變數
X_second_stage = pd.DataFrame.from_dict({'betas1': betas1, 'betas2': betas1, 'betas3': betas1, 'resid': resid_var})

# 添加截距项
X_second_stage = sm.add_constant(X_second_stage)

# 创建并拟合第二阶段线性回归模型
model_second_stage = sm.OLS(y_second_stage, X_second_stage).fit()
print(model_second_stage.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     29.85
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           5.60e-09
# Time:                        16:05:01   Log-Likelihood:                -32.237
# No. Observations:                  48   AIC:                             70.47
# Df Residuals:                      45   BIC:                             76.09
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8769      0.220      8.536      0.000       1.434       2.320
# betas1        -0.0320      0.065     -0.489      0.627      -0.164       0.100
# betas2        -0.0320      0.065     -0.489      0.627      -0.164       0.100
# betas3        -0.0320      0.065     -0.489      0.627      -0.164       0.100
# resid         -0.0313      0.004     -7.484      0.000      -0.040      -0.023
# ==============================================================================
# Omnibus:                       14.959   Durbin-Watson:                   1.635
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               22.443
# Skew:                           0.948   Prob(JB):                     1.34e-05
# Kurtosis:                       5.761   Cond. No.                     5.83e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.36e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
